# %%
# !python demo.py --isShow True
# Out:
# 2018-12-28 02:36:00.419062: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-12-28 02:36:00.561445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-28 02:36:00.561948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.15GiB
# 2018-12-28 02:36:00.561963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-28 02:36:00.816579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# !python demo_texture.py
# Out:
# 2018-12-27 16:23:12.555308: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-12-27 16:23:12.692279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-27 16:23:12.692803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.22GiB
# 2018-12-27 16:23:12.692855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-27 16:23:12.959355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# !python demo.py --help
# Out:
# usage: demo.py [-h] [-i INPUTDIR] [-o OUTPUTDIR] [--gpu GPU] [--isDlib ISDLIB]
#                [--is3d IS3D] [--isMat ISMAT] [--isKpt ISKPT] [--isPose ISPOSE]
#                [--isShow ISSHOW] [--isImage ISIMAGE] [--isFront ISFRONT]
#                [--isDepth ISDEPTH] [--isTexture ISTEXTURE] [--isMask ISMASK]
#                [--texture_size TEXTURE_SIZE]
#
# Joint 3D Face Reconstruction and Dense Alignment with Position Map Regression
# Network
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INPUTDIR, --inputDir INPUTDIR
#                         path to the input directory, where input images are
#                         stored.
#   -o OUTPUTDIR, --outputDir OUTPUTDIR
#                         path to the output directory, where results(obj,txt
#                         files) will be stored.
#   --gpu GPU             set gpu id, -1 for CPU
#   --isDlib ISDLIB       whether to use dlib for detecting face, default is
# ...

# %%
# !python demo_texture.py --help
# Out:
# usage: demo_texture.py [-h] [-i IMAGE_PATH] [-r REF_PATH] [-o OUTPUT_PATH]
#                        [--mode MODE] [--gpu GPU]
#
# Texture Editing by PRN
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i IMAGE_PATH, --image_path IMAGE_PATH
#                         path to input image
#   -r REF_PATH, --ref_path REF_PATH
#                         path to reference image(texture ref)
#   -o OUTPUT_PATH, --output_path OUTPUT_PATH
#                         path to save output
#   --mode MODE           ways to edit texture. 0 for modifying parts, 1 for
#                         changing whole
#   --gpu GPU             set gpu id, -1 for CPU

# %%
# python demo.py -i <inputDir> -o <outputDir> --isDlib True
# !python demo.py --isShow True -i test -o test/result --isDlib True
# Out:
# 2018-12-28 04:04:33.853011: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-12-28 04:04:33.991464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-28 04:04:33.991947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.15GiB
# 2018-12-28 04:04:33.991962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-28 04:04:34.245055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# python demo_texture.py -i image_path_1 -r image_path_2 -o output_path
# !python demo_texture.py -i test/2.jpg -r TestImages/trump.jpg -o test/result/output1.jpg
# Out:
# 2018-12-28 02:54:19.149466: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-12-28 02:54:19.286892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-28 02:54:19.287392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.15GiB
# 2018-12-28 02:54:19.287408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-28 02:54:19.542048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# python demo_texture.py -i image_path_1 -r image_path_2 -o output_path
# !python demo_texture.py -i test/3.jpg -r TestImages/trump.jpg -o test/result/output3.jpg
# Out:
# 2018-12-28 04:04:48.290588: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-12-28 04:04:48.431264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-28 04:04:48.431764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.15GiB
# 2018-12-28 04:04:48.431779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-28 04:04:48.685134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# !python demo_texture.py --help
# Out:
# usage: demo_texture.py [-h] [-i IMAGE_PATH] [-r REF_PATH] [-o OUTPUT_PATH]
#                        [--mode MODE] [--gpu GPU]
#
# Texture Editing by PRN
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i IMAGE_PATH, --image_path IMAGE_PATH
#                         path to input image
#   -r REF_PATH, --ref_path REF_PATH
#                         path to reference image(texture ref)
#   -o OUTPUT_PATH, --output_path OUTPUT_PATH
#                         path to save output
#   --mode MODE           ways to edit texture. 0 for modifying parts, 1 for
#                         changing whole
#   --gpu GPU             set gpu id, -1 for CPU

# %%
# !python demo_texture.py -i TestImages/emma.jpg -r TestImages/eye1.jpg -o test/result/emma_eye.jpg --mode 0
# Out:
# 2019-01-07 13:36:30.817191: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-01-07 13:36:31.015621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-01-07 13:36:31.016198: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.25GiB
# 2019-01-07 13:36:31.016231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2019-01-07 13:36:32.265805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# !python demo_texture.py -i TestImages/emma.jpg -r TestImages/mouse.jpg -o test/result/emma_mouse.jpg --mode 2
# Out:
# 2019-01-07 14:19:09.991427: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-01-07 14:19:10.136891: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-01-07 14:19:10.137454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.65
# pciBusID: 0000:01:00.0
# totalMemory: 10.73GiB freeMemory: 10.25GiB
# 2019-01-07 14:19:10.137486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2019-01-07 14:19:10.407303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...
